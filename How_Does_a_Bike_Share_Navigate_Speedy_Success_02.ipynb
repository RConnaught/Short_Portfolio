# %% [markdown]
# <a href="https://colab.research.google.com/github/RConnaught/Short_Portfolio/blob/master/How_Does_a_Bike_Share_Navigate_Speedy_Success_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cyclistic Trip Data
#
# This project is just a showcase of what I have learned throughout Coursera's Data Analytics Course and incorporating my knowledge of the Python language.
#
# As much as R is a useful language for statiscians, data analysts and the like. One cannot ignore the fact that Python is more in demand in terms of the job market.
#
# ### Scenario
#
# I am a junior data analyst working in the marketing analyst team at Cyclistic, a bike-share company in Chicago. The director of marketing believes the company’s future success depends on maximizing the number of annual memberships. Therefore, your team wants to understand how casual riders and annual members use Cyclistic bikes differently. From these insights,
# your team will design a new marketing strategy to convert casual riders into annual members. But first, Cyclistic executives must approve your recommendations, so they must be backed up with compelling data insights and professional data visualizations.

# %% [markdown]
# ### Ask
#
# Three question will quide the future marketing program:
#
# 1. How do annual members and casual rider use Cyclistic bikes differently?
# 2. Why would casual riders buy Cyclistic annual memberships?
# 3. How can Cyclistic use digital media to influence casual riders to become members?

# %% [markdown]
# ## Prepare
#
# Using the Cyclistic's historical trip data provided to analyze and identify trends. This is public data used to explore how different customer types are using Cyclistic bikes.
#
# **Note:** Due to data-privacy issues prohibit access to riders' personally identifiable information. Meaning, it won't be possible to connect pass purchases to credit card numbers to determine if casual riders live in the Cyclistic service area or if they have purchased multiple single passes.

# %% [markdown]
# ### Key tasks
#
# 1. Download data and store it appropriately
# 2. Identify how it's organized
# 3. Sort and filter the data

# %% [markdown]
# ## Process
#
# - The following below explains in detail what tools I'll use and why
# - The data I intent to use is the most recent, as of the creation of this notebook
# - The data has been correct and consistent with previous CSVs

# %% [markdown]
# ### Importing the following libraries for analysis
#
# - Pandas (for dataframe)
# - Glob (combining CSVs into one to use for later)
# - Datetime (to measure and analyze time)
# - Matplotlib (graphing)
# - Seaborn (same as above, informative graphics)

# %%
import pandas as pd
from glob import glob

# %%
data_files = sorted(glob('/content/drive/MyDrive/Cousera: Data Analyst/Data Analytics: Capstone/Week 02/Cyclistic Trip Data - 072022/202*.csv'))
data_files
# Out:
# ['/content/drive/MyDrive/Cousera: Data Analyst/Data Analytics: Capstone/Week 02/Cyclistic Trip Data - 072022/202106-divvy-tripdata.csv',
#  '/content/drive/MyDrive/Cousera: Data Analyst/Data Analytics: Capstone/Week 02/Cyclistic Trip Data - 072022/202107-divvy-tripdata.csv',
#  '/content/drive/MyDrive/Cousera: Data Analyst/Data Analytics: Capstone/Week 02/Cyclistic Trip Data - 072022/202108-divvy-tripdata.csv',
#  '/content/drive/MyDrive/Cousera: Data Analyst/Data Analytics: Capstone/Week 02/Cyclistic Trip Data - 072022/202109-divvy-tripdata.csv',
#  '/content/drive/MyDrive/Cousera: Data Analyst/Data Analytics: Capstone/Week 02/Cyclistic Trip Data - 072022/202110-divvy-tripdata.csv',
#  '/content/drive/MyDrive/Cousera: Data Analyst/Data Analytics: Capstone/Week 02/Cyclistic Trip Data - 072022/202111-divvy-tripdata.csv',
#  '/content/drive/MyDrive/Cousera: Data Analyst/Data Analytics: Capstone/Week 02/Cyclistic Trip Data - 072022/202112-divvy-tripdata.csv',
# ...

# %%
mergedata = pd.concat(pd.read_csv(datafile).assign(sourcefilename = datafile)
  for datafile in data_files)

# %%
mergedata.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  99FEC93BA843FB20  electric_bike  2021-06-13 14:31:28  2021-06-13 14:34:11
# 1  06048DCFC8520CAF  electric_bike  2021-06-04 11:18:02  2021-06-04 11:24:19
# 2  9598066F68045DF2  electric_bike  2021-06-04 09:49:35  2021-06-04 09:55:34
# 3  B03C0FE48C412214  electric_bike  2021-06-03 19:56:05  2021-06-03 20:21:55
# 4  B9EEA89F8FEE73B7  electric_bike  2021-06-04 14:05:51  2021-06-04 14:09:59
#
#   start_station_name start_station_id end_station_name end_station_id  \
# 0                NaN              NaN              NaN            NaN
# 1                NaN              NaN              NaN            NaN
# 2                NaN              NaN              NaN            NaN
# 3                NaN              NaN              NaN            NaN
# 4                NaN              NaN              NaN            NaN
#
#    start_lat  start_lng  end_lat  end_lng member_casual  \
# ...

# %%
mergedata.to_csv('/content/drive/MyDrive/Cousera: Data Analyst/Data Analytics: Capstone/Week 02/Cyclistic trip data/2021_to_2022-divvy-tripdata2.csv')

# %% [markdown]
# ## Analyze
#
# - Organize the data to perform analysis on it
# - Properly format the data
# - Find surprises in the data
# - What trends or relationships are found in the data?
# - How such insights help answer the business questions?

# %%
import datetime as dt 

cyclistic = pd.read_csv('/content/drive/MyDrive/Cousera: Data Analyst/Data Analytics: Capstone/Week 02/Cyclistic trip data/2021 to 2022-divvy-tripdata.csv', parse_dates=True)

# %%
cyclistic.head(8)
# Out:
#    Unnamed: 0           ride_id  rideable_type           started_at  \
# 0           0  C809ED75D6160B2A  electric_bike  2021-05-30 11:58:15
# 1           1  DD59FDCE0ACACAF3  electric_bike  2021-05-30 11:29:14
# 2           2  0AB83CB88C43EFC2  electric_bike  2021-05-30 14:24:01
# 3           3  7881AC6D39110C60  electric_bike  2021-05-30 14:25:51
# 4           4  853FA701B4582BAF  electric_bike  2021-05-30 18:15:39
# 5           5  F5E63DFD96B2A737  electric_bike  2021-05-30 11:33:41
# 6           6  C884951E36656727  electric_bike  2021-05-30 10:51:37
# 7           7  48B60B250FE75AF9  electric_bike  2021-05-05 13:57:03
#
#               ended_at start_station_name start_station_id end_station_name  \
# 0  2021-05-30 12:10:39                NaN              NaN              NaN
# 1  2021-05-30 12:14:09                NaN              NaN              NaN
# 2  2021-05-30 14:25:13                NaN              NaN              NaN
# ...

# %%
# Size of the dataframe
cyclistic.size
# Out:
# 86363265

# %%
# Shape of the dataframe
cyclistic.shape
# Out:
# (5757551, 15)

# %%
# Number of dimensions in dataframe
cyclistic.ndim
# Out:
# 2

# %%
# List of columns in the dataframe
list(cyclistic.columns.values)
# Out:
# ['Unnamed: 0',
#  'ride_id',
#  'rideable_type',
#  'started_at',
#  'ended_at',
#  'start_station_name',
#  'start_station_id',
#  'end_station_name',
#  'end_station_id',
#  'start_lat',
#  'start_lng',
#  'end_lat',
#  'end_lng',
#  'member_casual',
#  'sourcefilename']

# %%
# The data types of the dataframe
cyclistic.dtypes
# Out:
# Unnamed: 0              int64
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# sourcefilename         object
# dtype: object

# %% [markdown]
# Display the descriptive analysis of the dataframe

# %%
pd.options.display.float_format = '{:.2f}'.format
cyclistic.describe()
# Out:
#        Unnamed: 0  start_lat  start_lng    end_lat    end_lng
# count  5757551.00 5757551.00 5757551.00 5752785.00 5752785.00
# mean    307594.43      41.90     -87.65      41.90     -87.65
# std     215672.65       0.05       0.03       0.05       0.03
# min          0.00      41.64     -87.84      41.39     -88.97
# 25%     122000.00      41.88     -87.66      41.88     -87.66
# 50%     267984.00      41.90     -87.64      41.90     -87.64
# 75%     472662.00      41.93     -87.63      41.93     -87.63
# max     822409.00      45.64     -73.80      42.17     -87.49

# %%
cyc_all_trips = cyclistic.drop(columns=['Unnamed: 0', 'sourcefilename'])

# %%
cyc_all_trips.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  C809ED75D6160B2A  electric_bike  2021-05-30 11:58:15  2021-05-30 12:10:39
# 1  DD59FDCE0ACACAF3  electric_bike  2021-05-30 11:29:14  2021-05-30 12:14:09
# 2  0AB83CB88C43EFC2  electric_bike  2021-05-30 14:24:01  2021-05-30 14:25:13
# 3  7881AC6D39110C60  electric_bike  2021-05-30 14:25:51  2021-05-30 14:41:04
# 4  853FA701B4582BAF  electric_bike  2021-05-30 18:15:39  2021-05-30 18:22:32
#
#   start_station_name start_station_id end_station_name end_station_id  \
# 0                NaN              NaN              NaN            NaN
# 1                NaN              NaN              NaN            NaN
# 2                NaN              NaN              NaN            NaN
# 3                NaN              NaN              NaN            NaN
# 4                NaN              NaN              NaN            NaN
#
#    start_lat  start_lng  end_lat  end_lng member_casual
# ...

# %%
cyc_all_trips.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# dtype: object

# %%
cyc_all_trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5757551 entries, 0 to 5757550
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          object
#  3   ended_at            object
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: float64(4), object(9)
# memory usage: 571.0+ MB

# %%
cyc_all_trips['started_at'] = pd.to_datetime(cyc_all_trips['started_at'])
cyc_all_trips['ended_at'] = pd.to_datetime(cyc_all_trips['ended_at'])

# %%
cyc_all_trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5757551 entries, 0 to 5757550
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          datetime64[ns]
#  3   ended_at            datetime64[ns]
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: datetime64[ns](2), float64(4), object(7)
# memory usage: 571.0+ MB

# %%
cyc_all_trips['ride_length'] = cyc_all_trips['ended_at'] - cyc_all_trips['started_at']

# %%
cyc_all_trips.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  C809ED75D6160B2A  electric_bike 2021-05-30 11:58:15 2021-05-30 12:10:39
# 1  DD59FDCE0ACACAF3  electric_bike 2021-05-30 11:29:14 2021-05-30 12:14:09
# 2  0AB83CB88C43EFC2  electric_bike 2021-05-30 14:24:01 2021-05-30 14:25:13
# 3  7881AC6D39110C60  electric_bike 2021-05-30 14:25:51 2021-05-30 14:41:04
# 4  853FA701B4582BAF  electric_bike 2021-05-30 18:15:39 2021-05-30 18:22:32
#
#   start_station_name start_station_id end_station_name end_station_id  \
# 0                NaN              NaN              NaN            NaN
# 1                NaN              NaN              NaN            NaN
# 2                NaN              NaN              NaN            NaN
# 3                NaN              NaN              NaN            NaN
# 4                NaN              NaN              NaN            NaN
#
#    start_lat  start_lng  end_lat  end_lng member_casual     ride_length
# ...

# %%
cyc_all_trips['Month'] = cyc_all_trips['started_at'].dt.month
cyc_all_trips['Day'] = cyc_all_trips['started_at'].dt.weekday

# %%
cyc_all_trips.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  C809ED75D6160B2A  electric_bike 2021-05-30 11:58:15 2021-05-30 12:10:39
# 1  DD59FDCE0ACACAF3  electric_bike 2021-05-30 11:29:14 2021-05-30 12:14:09
# 2  0AB83CB88C43EFC2  electric_bike 2021-05-30 14:24:01 2021-05-30 14:25:13
# 3  7881AC6D39110C60  electric_bike 2021-05-30 14:25:51 2021-05-30 14:41:04
# 4  853FA701B4582BAF  electric_bike 2021-05-30 18:15:39 2021-05-30 18:22:32
#
#   start_station_name start_station_id end_station_name end_station_id  \
# 0                NaN              NaN              NaN            NaN
# 1                NaN              NaN              NaN            NaN
# 2                NaN              NaN              NaN            NaN
# 3                NaN              NaN              NaN            NaN
# 4                NaN              NaN              NaN            NaN
#
#    start_lat  start_lng  end_lat  end_lng member_casual     ride_length  \
# ...

# %%
ride_weekday = cyc_all_trips[cyc_all_trips.columns[-3:-1]]

# %%
ride_weekday.describe()
# Out:
#                      ride_length      Month
# count                    5757551 5757551.00
# mean   0 days 00:21:08.298277687       7.29
# std    0 days 02:52:02.845900743       2.58
# min            -1 days +23:01:58       1.00
# 25%              0 days 00:06:27       6.00
# 50%              0 days 00:11:31       7.00
# 75%              0 days 00:20:57       9.00
# max             38 days 20:24:09      12.00

# %%
ride_weekday2 = cyc_all_trips.loc[0:, ['member_casual', 'ride_length', 'Day']]

# %%
ride_weekday2.describe()
# Out:
#                      ride_length        Day
# count                    5757551 5757551.00
# mean   0 days 00:21:08.298277687       3.15
# std    0 days 02:52:02.845900743       2.00
# min            -1 days +23:01:58       0.00
# 25%              0 days 00:06:27       1.00
# 50%              0 days 00:11:31       3.00
# 75%              0 days 00:20:57       5.00
# max             38 days 20:24:09       6.00

# %%
ride_weekday2[ride_weekday2['member_casual'] == 'casual'].describe()
# Out:
#                      ride_length        Day
# count                    2536358 2536358.00
# mean   0 days 00:31:17.446360095       3.48
# std    0 days 04:17:02.492545751       2.01
# min            -1 days +23:01:58       0.00
# 25%              0 days 00:08:50       2.00
# 50%              0 days 00:15:34       4.00
# 75%              0 days 00:28:29       5.00
# max             38 days 20:24:09       6.00

# %%
ride_weekday2[ride_weekday2['member_casual'] == 'member'].describe()
# Out:
#                      ride_length        Day
# count                    3221193 3221193.00
# mean   0 days 00:13:08.656849186       2.89
# std    0 days 00:27:10.926151771       1.95
# min            -1 days +23:05:55       0.00
# 25%              0 days 00:05:20       1.00
# 50%              0 days 00:09:11       3.00
# 75%              0 days 00:15:56       5.00
# max              1 days 01:59:54       6.00

# %%
(3300919 - 2559857) / 2559857
# Out:
# 0.2894935146767964

# %% [markdown]
# ## Difference among riders
#
# Visualize the difference among riders

# %%
cyc_all_trips['member_casual'].value_counts()
# Out:
# member    3221193
# casual    2536358
# Name: member_casual, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

cyc_all_trips.groupby('member_casual')['member_casual'].count().plot(kind='pie', autopct='%8.0f%%')

plt.title('Casual v. Membership riders')
# Out:
# Text(0.5, 1.0, 'Casual v. Membership riders')

# %%
import plotly.express as px

#riders_df = cyc_all_trips['member_casual'].value_counts()
fig = px.pie(cyc_all_trips, values='member_casual', title='Casual v. Membership riders')
fig.show()

# %%
sns.set_style('whitegrid')
sns.countplot(x='Day', hue='member_casual', data=cyc_all_trips)

# %%
sns.countplot(x='rideable_type', hue='member_casual', data=cyc_all_trips)

# %%
sns.catplot(x='Month', hue='member_casual', col='rideable_type',
            data=cyc_all_trips, kind='count',
            height=5, aspect=.8)

# %%
# Provide day of week with name
cyc_all_trips['day_of_week'] = cyc_all_trips['started_at'].dt.day_name()

# %%
sns.set_style('whitegrid')
sns.countplot(x='day_of_week', hue='member_casual', data=cyc_all_trips)

# %% [markdown]
# ## Share
#
# Takeaway from analysis
#
# - Although there are more riders with membership than casuals, the latter tend to use more bikes than those with membership during the weekend
# - Casuals riders tend to ride more than twice as much on average than their counterparts with membership
# - The classic bike seems to be vastly popular among riders, regardless of membership
# - August is the most popular month for membership riders using classic bikes, while June is the popular month for casuals
# - Among electric bike, between May and October seems to be the most popular months for membership riders, while July is the most popular with casuals
#  - Although, the spike in popularity isn't anything to brag about

# %%
member_by_days = cyc_all_trips.groupby(['member_casual', 'day_of_week'])

# %%
avg_ride_length2 = member_by_days.ride_length.agg(['mean'])

# %%
avg_ride_length2.to_csv('/content/drive/MyDrive/Cousera: Data Analyst/Data Analytics: Capstone/Week 02/avg_ride_length2021-22.csv')

# %% [markdown]
# ## Act
#
# Based on the takeaway of the share portion, perhaps the company should promote a discount sale of some kind during the weekend. The promotion should start in the middle of the year when ridership is at its highest.
